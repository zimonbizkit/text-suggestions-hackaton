# %% [markdown]
# ## Doing spatial requests
#
# In order to do regular spatial requests, we need the following data
#  - The users location (specified in (lat,lon) format, currently set in Barcelona area)
#  - The greater circle in kilometers for which we would like to limit the spatial search (two kilometers)
#  - A regular user query (*:*, for example)
#  - The spatial field to filter and order by (location)
#
# As extra parameters, we need to tell that the Filter Query would use the **geofilt!** functionality where the greater circle is the one specified above.
#
# Below we perform only a star-doublecolon-star query, but getting the results in 2kms distance

# %%
import requests

# barcelona #41.3990912,2.1657931 #_radius=30
#zaragoza #41.622393,-0.9108323 #_radius=120
_url = "http://solr:8983/solr/retrotech/select"
_params = {
    'defType': "edismax",
    'fq': "{!geofilt}",          # filter query that applies the geofilt function given a distance 'd' 
    'q.op':"OR",
    'd':"5",                     # greater circle distance in kilometers
    'pt':"41.3990912,2.1657931", # latitude and longitude of point (Barcelona city)
    'sfield': "location",         # spatial field for filtering and sorting
    'rows': "900",
    'q':"*:*",
    'qf':"name",
    'fl':"name,location,geohash",
    'debugQuery':"true"

}

url = "http://0.0.0.0:8983/solr/retrotech/select"# ?debugQuery=true&defType="+_deftype+"&fl"+_fl+"&fq="+_fq+"&indent=true&q.op=OR&q=*:*&qf=name&rows=900&d=2&pt="+_pt+"&sfield="+_sfield+"&spatial=true"

data = requests.get(url = _url, params = _params).json()

# %% [markdown]
# Below list should give you list of names of the product and its latitude and longitude. Please note how we got 16 results instead of 900. This is because we are only getting results in 5 kms distance.

# %%
print(*((x['name'],x['location']) for x in data['response']['docs']), sep='\n')
# Out:
# ('Samsung - 64\\ Class - Plasma - 1080p - 600Hz - Smart - 3D - HDTV"', '41.3700889,2.1307976')
# ('Samsung - 22\\ Class / 1080p / 60Hz / LCD HDTV"', '41.3700889,2.1307976')
# ('Bulletproof Monk - Widescreen - Blu-ray Disc', '41.3993586,2.1976986')
# ('Phineas & Ferb: The Fast and the Phineas - Fullscreen - DVD', '41.3700889,2.1307976')
# ('Western Digital - My Passport Essential 500GB External USB 3.0/2.0 Portable Hard Drive - Real Red', '41.3700889,2.1307976')
# ('Tribeca - Atlanta Braves Case for Apple&#xAE; iPhone&#xAE; 4 - Dark Blue', '41.3700889,2.1307976')
# ('Metra - Turbokits Aftermarket Radio Wire Harness Adapter for Select Ford Vehicles', '41.3700889,2.1307976')
# ('Believers [LP] - VINYL', '41.4080147,2.2091094')
# ('I Never Promised You a Rose Garden: A Portrait of David Toop Through His Record Collection - DVD', '41.3700889,2.1307976')
# ('Scosche - Showtime Composite Video Cable for Apple&#xAE; iPod&#xAE; and iPhone', '41.3700889,2.1307976')
# ('Honeywell - Easy-to-Care 1 Gal. Cool Moisture Humidifier - White', '41.3700889,2.1307976')
# ('Scary Movie 3 - Special - DVD', '41.3700889,2.1307976')
# ('Transgression [ECD] [DualDisc] - CD', '41.3700889,2.1307976')
# ('Samsung - 46\\ Class - LCD - 1080p - 60Hz - HDTV"', '41.3993586,2.1976986')
# ('Magnificent Adventures Of Heartache & Other - CD', '41.3700889,2.1307976')
# ('GE - Caf&#xE9; 30\\ Self-Cleaning Freestanding Electric Convection Range - Stainless-Steel"', '41.3700889,2.1307976')

# %% [markdown]
# ### Suggestions time?
#
# This same logic is the one used with the `suggest` component, that was extended with geospatial features, where the lookup implementation would factor in the geospatial score. This combination was achieved like that and with some custom joint-queries and subqueries.
#
# I could not bring that customisation on this hands-on , sorry D:
#
#
# But for the sake of getting results over suggestions without the suggester component, we are doing a regular query to have distance-based results, with some tweaks as below 👇🏻
#  - Enlarging our greater circle radius **(to 30 kms)**
#  - Doing a very recall-oriented autocomplete request, with the term **"DVD"**
#  - With doing a "like" query using the Extended Dismax parser
#
#
#
# We could boost the item titles by giving more weight to the prefixed ones, but for this example we won't do it.

# %%
_q="DVD"
# barcelona #41.3990912,2.1657931 #_radius=30
#zaragoza #41.622393,-0.9108323 #_radius=120
_point="41.3990912,2.1657931" # 
_url = "http://solr:8983/solr/retrotech/select"
_radius=30
#_radius=120 # zaragoza
_params = {
    'defType': "edismax",
    'fq': "{!geofilt}",          # filter query that applies the geofilt function given a distance 'd' 
    'q.op':"OR",
    'd':_radius,                     # greater circle distance in kilometers
    'pt':"41.3990912,2.1657931", # latitude and longitude of point
#   'pt':"41.622393,-0.9108323", # latitude and longitude of point in zaragoza
    'sfield': "location",         # spatial field for filtering and sorting
    'rows': "90",
    'q':"name:*"+_q+"*",          #ugly but working nonetheless
    'qf':"name",
    'fl':"name,location,geohash",
    'debugQuery':"true",
    #'facet': 'true',
    #'facet.field': 'name',
    #'f.names.facet.prefix':"$"+_p+"$"
}

url = "http://0.0.0.0:8983/solr/retrotech/select"# ?debugQuery=true&defType="+_deftype+"&fl"+_fl+"&fq="+_fq+"&indent=true&q.op=OR&q=*:*&qf=name&rows=900&d=2&pt="+_pt+"&sfield="+_sfield+"&spatial=true"

data = requests.get(url = _url, params = _params)
print(data.text)
# Out:
# {
#   "responseHeader":{
#     "status":0,
#     "QTime":529,
#     "params":{
#       "q":"name:*DVD*",
#       "defType":"edismax",
#       "d":"30",
#       "pt":"41.3990912,2.1657931",
#       "qf":"name",
#       "fl":"name,location,geohash",
#       "q.op":"OR",
#       "fq":"{!geofilt}",
#       "sfield":"location",
#       "rows":"90",
#       "debugQuery":"true"}},
#   "response":{"numFound":655,"start":0,"numFoundExact":true,"docs":[
#       {
#         "name":"Of Mice and Men - DVD",
#         "location":"41.4970697,2.3214331",
#         "geohash":"sp3sh"},
#       {
#         "name":"Night of the Living Dead/Sleepy Hollow High [2 Discs] - Box - DVD",
#         "location":"41.5393484,2.2130934",
#         "geohash":"sp3s6"},
#       {
#         "name":"Moral Orel, Vol. 1: The Unholy Version [2 Discs] - Uncensored Special - DVD",
#         "location":"41.3163083,2.0156034",
#         "geohash":"sp37j"},
#       {
#         "name":"Half Nelson - Widescreen Subtitle AC3 Dolby - DVD",
#         "location":"41.5398348,2.4448926",
#         "geohash":"sp3sr"},
#       {
#         "name":"Wonderland - Widescreen Subtitle - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"NBA Indiana Pacers Greatest Game Collection 1 - DVD",
#         "location":"41.3246333,2.0952568",
#         "geohash":"sp37p"},
#       {
#         "name":"George Lopez: The Complete 1st & 2nd Seasons [4 Discs] - DVD",
#         "location":"41.5393484,2.2130934",
#         "geohash":"sp3s6"},
#       {
#         "name":"Toshiba - 9\\ Widescreen Portable DVD Player with Dual Headphone Jacks\"",
#         "location":"41.4515626,2.2083371",
#         "geohash":"sp3ef"},
#       {
#         "name":"Star Knight - Fullscreen Dolby - DVD",
#         "location":"41.4716695,2.1798272",
#         "geohash":"sp3ec"},
#       {
#         "name":"The Condemned - Fullscreen Subtitle AC3 Dolby - DVD",
#         "location":"41.3687006,2.0174512",
#         "geohash":"sp37m"},
#       {
#         "name":"Mobile Suit Gundam Seed Destiny, Vol. 10 [Special Edition] [With T-shirt] - DVD",
#         "location":"41.5873942,2.1806823",
#         "geohash":"sp3s9"},
#       {
#         "name":"Misery - Widescreen Collector's Dubbed - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Beef IV - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Antony and Cleopatra - DVD",
#         "location":"41.6110502,2.1374456",
#         "geohash":"sp3s8"},
#       {
#         "name":"Megadeth: Rust in Peace - Live - DVD",
#         "location":"41.4493539,2.248254",
#         "geohash":"sp3eg"},
#       {
#         "name":"PENGUINS OF MADAGASCAR: I WAS A PENGUIN ZOMBIE - DVD",
#         "location":"41.4936194,2.0319476",
#         "geohash":"sp3kn"},
#       {
#         "name":"Bee Gees: One Night Only - Anniversary Dolby - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"The Human Centipede - DVD",
#         "location":"41.5629623,2.0100492",
#         "geohash":"sp3km"},
#       {
#         "name":"America: The Story of Us [3 Discs] - DVD",
#         "location":"41.5421013,2.1138977",
#         "geohash":"sp3s2"},
#       {
#         "name":"Opeth: In Live Concert at the Royal Albert Hall - DVD",
#         "location":"41.5421013,2.1138977",
#         "geohash":"sp3s2"},
#       {
#         "name":"Eric Sardinas and Big Motor: Live - DVD",
#         "location":"41.4728432,2.0817809",
#         "geohash":"sp37z"},
#       {
#         "name":"Cape: The Complete Series [2 Discs] - Widescreen Subtitle AC3 Dolby - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Psych: The Complete Fifth Season [4 Discs] - Widescreen Subtitle AC3 - DVD",
#         "location":"41.4716695,2.1798272",
#         "geohash":"sp3ec"},
#       {
#         "name":"Ricky Dillard and New G: Keep Living - DVD",
#         "location":"41.4666983,2.2789654",
#         "geohash":"sp3eg"},
#       {
#         "name":"Somewhere in the Stratosphere [CD & DVD] [Box] - CD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Science & Faith [CD & DVD] - CD",
#         "location":"41.3163083,2.0156034",
#         "geohash":"sp37j"},
#       {
#         "name":"DVD",
#         "location":"41.6079555,2.2876008",
#         "geohash":"sp3ss"},
#       {
#         "name":"Harold and Kumar Escape from Guantanamo Bay - Widescreen - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Lost Boys: The Tribe - Widescreen Uncut Subtitle - DVD",
#         "location":"41.3163083,2.0156034",
#         "geohash":"sp37j"},
#       {
#         "name":"Phineas & Ferb: The Fast and the Phineas - Fullscreen - DVD",
#         "location":"41.3700889,2.1307976",
#         "geohash":"sp3e2"},
#       {
#         "name":"Daft Punk's Electroma - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Slipknot: (Sic)nesses - Live at Download - DVD",
#         "location":"41.4493539,2.248254",
#         "geohash":"sp3eg"},
#       {
#         "name":"Hellbilly Deluxe,... [CD & DVD] [PA] [Digipak] - CD",
#         "location":"41.6110502,2.1374456",
#         "geohash":"sp3s8"},
#       {
#         "name":"Connie Talbot: Holiday Magic - DVD",
#         "location":"41.6079555,2.2876008",
#         "geohash":"sp3ss"},
#       {
#         "name":"Air Buddies/Snow Buddies/Space Buddies/Santa Buddies [4 Discs] - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Five Fingers - Widescreen Subtitle AC3 Dolby - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Aleratec - Tower Publisher 20x External USB 2.0 DVD&#xB1;RW/CD-RW Drive",
#         "location":"41.3246333,2.0952568",
#         "geohash":"sp37p"},
#       {
#         "name":"UFC 120: Bisping vs. Akiyama - DVD",
#         "location":"41.3246333,2.0952568",
#         "geohash":"sp37p"},
#       {
#         "name":"Scooby-Doo and the Ghoul School - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Gremlins 2: The New Batch - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Mystery Science Theater 3000: Red Zone Cuba - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Thunderbolt and Lightfoot - Widescreen - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Peep and the Big Wide World: Chirp Flies - DVD",
#         "location":"41.3459033,2.0413673",
#         "geohash":"sp37n"},
#       {
#         "name":"Warren Miller's Riders Collection [3 Discs / Box Set] - Box Collector's AC3 Dolby - DVD",
#         "location":"41.5398348,2.4448926",
#         "geohash":"sp3sr"},
#       {
#         "name":"Tarzan - Special - DVD",
#         "location":"41.6079555,2.2876008",
#         "geohash":"sp3ss"},
#       {
#         "name":"The Emperor's New Groove - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Fullmetal Alchemist 6: Captured Souls [Subtitles / Uncut] - Uncut Subtitle - DVD",
#         "location":"41.5629623,2.0100492",
#         "geohash":"sp3km"},
#       {
#         "name":"Bluegrass Journey - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"JVC - 50W x 4 MOSFET Apple&#xAE; iPod&#xAE;/Satellite Radio-/HD-Ready In-Dash DVD Deck",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Jensen - 40W x 4 Apple&#xAE; iPod&#xAE;-Ready In-Dash DVD Deck",
#         "location":"41.5398348,2.4448926",
#         "geohash":"sp3sr"},
#       {
#         "name":"Heroes Of Bikini Bottom - Fullscreen - DVD",
#         "location":"41.5421013,2.1138977",
#         "geohash":"sp3s2"},
#       {
#         "name":"Big Time Rush: Season One, Vol. 2 [2 Discs] - Fullscreen Dolby - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"happythankyoumoreplease - DVD",
#         "location":"41.3459033,2.0413673",
#         "geohash":"sp37n"},
#       {
#         "name":"Oblivion - DVD",
#         "location":"41.4515626,2.2083371",
#         "geohash":"sp3ef"},
#       {
#         "name":"American Dad, Vol. 5 [3 Discs] - Fullscreen Subtitle AC3 Dolby - DVD",
#         "location":"41.355724,2.0706225",
#         "geohash":"sp37r"},
#       {
#         "name":"Mary and Max - DVD",
#         "location":"41.5421013,2.1138977",
#         "geohash":"sp3s2"},
#       {
#         "name":"La Vida Loca - Subtitle - DVD",
#         "location":"41.4728432,2.0817809",
#         "geohash":"sp37z"},
#       {
#         "name":"Kevin Hart: Seriously Funny - DVD",
#         "location":"41.5873365,2.3260575",
#         "geohash":"sp3ss"},
#       {
#         "name":"Rampage - Subtitle - DVD",
#         "location":"41.2861022,1.9824173",
#         "geohash":"sp36v"},
#       {
#         "name":"Love for Sale - Widescreen Subtitle AC3 Dolby - DVD",
#         "location":"41.5629623,2.0100492",
#         "geohash":"sp3km"},
#       {
#         "name":"LeapFrog: Math Adventure to the Moon/Letter Factory - Fullscreen - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"National Geographic: Dinosaurs Decoded - Widescreen AC3 Dolby - DVD",
#         "location":"41.4819226,2.2689473",
#         "geohash":"sp3eg"},
#       {
#         "name":"The Job - Widescreen Subtitle Dolby - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"The Dark Knight - Fullscreen AC3 Dolby - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"The Great Escape - Widescreen - DVD",
#         "location":"41.5421013,2.1138977",
#         "geohash":"sp3s2"},
#       {
#         "name":"Multiplicity - Fullscreen - DVD",
#         "location":"41.5393484,2.2130934",
#         "geohash":"sp3s6"},
#       {
#         "name":"To Kill a Mockingbird - Widescreen Collector's Dubbed - DVD",
#         "location":"41.5122172,2.2379134",
#         "geohash":"sp3s4"},
#       {
#         "name":"Shopgirl - Widescreen Dubbed Subtitle AC3 - DVD",
#         "location":"41.4936194,2.0319476",
#         "geohash":"sp3kn"},
#       {
#         "name":"My Name Is Bill W. - Subtitle - DVD",
#         "location":"41.5629623,2.0100492",
#         "geohash":"sp3km"},
#       {
#         "name":"Musique, Vol. 1: 1993-2005 [CD & DVD] - CD",
#         "location":"41.5172534,2.1265942",
#         "geohash":"sp3s0"},
#       {
#         "name":"XXX (2002) - Blu-ray-DVD",
#         "location":"41.4932429,1.8747348",
#         "geohash":"sp3k4"},
#       {
#         "name":"House Of Flying Daggers - Blu-ray-DVD",
#         "location":"41.4910324,2.1374969",
#         "geohash":"sp3s0"},
#       {
#         "name":"Ultimate Dambusters Collection (3 Disc) - DVD",
#         "location":"41.4910324,2.1374969",
#         "geohash":"sp3s0"},
#       {
#         "name":"The Nanny Express - Fullscreen - DVD",
#         "location":"41.6523952,2.229264",
#         "geohash":"sp3sf"},
#       {
#         "name":"Halloween III: Season of the Witch - Widescreen Subtitle Dolby - DVD",
#         "location":"41.3163083,2.0156034",
#         "geohash":"sp37j"},
#       {
#         "name":"Dennis Chambers: In the Pocket - DVD",
#         "location":"41.355724,2.0706225",
#         "geohash":"sp37r"},
#       {
#         "name":"Dark Shadows: Collection 9 [4 Discs] - DVD",
#         "location":"41.3459033,2.0413673",
#         "geohash":"sp37n"},
#       {
#         "name":"Iron Man 2 [CD & DVD] - CD",
#         "location":"41.3815832,2.0750677",
#         "geohash":"sp37r"},
#       {
#         "name":"Garmin - TOPO U.S. 24K Northeast DVD",
#         "location":"41.422188,1.9966632",
#         "geohash":"sp37t"},
#       {
#         "name":"Couples Retreat - Widescreen Dubbed Subtitle AC3 - DVD",
#         "location":"41.355724,2.0706225",
#         "geohash":"sp37r"},
#       {
#         "name":"Away We Go - Widescreen Dubbed Subtitle AC3 - DVD",
#         "location":"41.5515189,2.2480812",
#         "geohash":"sp3s7"},
#       {
#         "name":"Epson - PowerLite Presenter WXGA Projector with DVD Player",
#         "location":"41.4515626,2.2083371",
#         "geohash":"sp3ef"},
#       {
#         "name":"In the Court of the Crimson King... [CD & DVD] - CD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Anne of Green Gables: A New Beginning - Widescreen Special - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"He-Man & The Masters Of Universe: Comp Series - DVD",
#         "location":"41.6079555,2.2876008",
#         "geohash":"sp3ss"},
#       {
#         "name":"Dragon Ball: Season 2 (5 Disc) - Box - DVD",
#         "location":"41.632265,2.1676442",
#         "geohash":"sp3sc"},
#       {
#         "name":"Bridge to Terabithia - Widescreen Dubbed Subtitle AC3 - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Little Einsteins: Rocket's Firebird Rescue - Dubbed AC3 Dolby - DVD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Come What(ever)... [CD & DVD] [PA] - CD",
#         "location":"41.3598601,2.0997927",
#         "geohash":"sp37r"},
#       {
#         "name":"Dog the Bounty Hunter: The Best of Seasons 1, 2 and 3 [4 Discs] - DVD",
#         "location":"41.5421013,2.1138977",
#         "geohash":"sp3s2"}]
#   },
#   "debug":{
#     "rawquerystring":"name:*DVD*",
#     "querystring":"name:*DVD*",
#     "parsedquery":"+name:*DVD*",
#     "parsedquery_toString":"+name:*DVD*",
#     "explain":{
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n",
#       "":"\n1.0 = name:*DVD*\n"},
#     "QParser":"ExtendedDismaxQParser",
#     "altquerystring":null,
#     "boost_queries":null,
#     "parsed_boost_queries":[],
#     "boostfuncs":null,
#     "filter_queries":["{!geofilt}"],
#     "parsed_filter_queries":["LatLonPointDistanceQuery(location:41.3990912,2.1657931 +/- 30000.000000000004 meters)"],
#     "timing":{
#       "time":528.0,
#       "prepare":{
#         "time":7.0,
#         "query":{
#           "time":6.0},
#         "facet":{
#           "time":0.0},
#         "facet_module":{
#           "time":0.0},
#         "mlt":{
#           "time":0.0},
#         "highlight":{
#           "time":0.0},
#         "stats":{
#           "time":0.0},
#         "expand":{
#           "time":0.0},
#         "terms":{
#           "time":0.0},
#         "debug":{
#           "time":0.0}},
#       "process":{
#         "time":518.0,
#         "query":{
#           "time":16.0},
#         "facet":{
#           "time":0.0},
#         "facet_module":{
#           "time":0.0},
#         "mlt":{
#           "time":0.0},
#         "highlight":{
#           "time":0.0},
#         "stats":{
#           "time":0.0},
#         "expand":{
#           "time":0.0},
#         "terms":{
#           "time":0.0},
#         "debug":{
#           "time":502.0}}}}}

# %% [markdown]
# Let's plot them on a map now so we can see it :D

# %%
from ipyleaflet import Map, basemaps, Circle
_json = data.json()

# barcelona #41.3990912,2.1657931
#zaragoza #41.622393,-0.9108323

center = [41.3990912,2.1657931]
#center = [41.622393,-0.9108323] #zaragoza
zoom = 8

m = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=center, zoom=zoom)

for r in _json['response']['docs']:
    p = Circle()
    p.radius=2
    p.weight=2
    p.color="blue"
    p.fill_color="blue"
    p.location = tuple(r['location'].split(','))
    m.add(p)
m


r = Circle()
r.radius = _radius*1000
r.weight=2
r.color = "orange"
r.fill_color = "orange"
_bcn_latlon = (41.3990912,2.1657931)
#_bcn_latlon = (41.622393,-0.9108323)

r.location = _bcn_latlon
m.add(r)
m
# Out:
# Map(center=[41.3990912, 2.1657931], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…
